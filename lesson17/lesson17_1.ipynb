# %% [markdown]
# ### https://www.perplexity.ai/search/541099c9-ea3f-4aaa-98b2-53af4156f3cc

# %% [markdown]
# ## 需要安裝jinja2套件

# %%
#styler.format()
#style.format_index()
#style.relabel_index
import pandas as pd
import numpy as np

df = pd.DataFrame({
    "strings": ["Adam", "Mike"],
    "ints": [1, 3],
    "floats": [1.123, 1000.23]
})
type(df.style)

display(df)
s = df.style\
.format(precision=3, thousands=",", decimal='.')\
.format_index(str.upper,axis=1)\
.relabel_index(["列1","列2"])

s
# Out:
#   strings  ints    floats
# 0    Adam     1     1.123
# 1    Mike     3  1000.230
# <style type="text/css">
# </style>
# <table id="T_e4b92">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e4b92_level0_col0" class="col_heading level0 col0" >STRINGS</th>
#       <th id="T_e4b92_level0_col1" class="col_heading level0 col1" >INTS</th>
#       <th id="T_e4b92_level0_col2" class="col_heading level0 col2" >FLOATS</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e4b92_level0_row0" class="row_heading level0 row0" >列1</th>
#       <td id="T_e4b92_row0_col0" class="data row0 col0" >Adam</td>
#       <td id="T_e4b92_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_e4b92_row0_col2" class="data row0 col2" >1.123</td>
#     </tr>
#     <tr>
#       <th id="T_e4b92_level0_row1" class="row_heading level0 row1" >列2</th>
#       <td id="T_e4b92_row1_col0" class="data row1 col0" >Mike</td>
#       <td id="T_e4b92_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_e4b92_row1_col2" class="data row1 col2" >1,000.230</td>
#     </tr>
#   </tbody>
# </table>

# %%
weather_df = pd.DataFrame(np.random.rand(50,2)*5,
                          index=pd.date_range(start="2024-01-01", periods=50),
                          columns=["Tokyo","Taipei"]
                          )
weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 50 entries, 2024-01-01 to 2024-02-19
# Freq: D
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Tokyo   50 non-null     float64
#  1   Taipei  50 non-null     float64
# dtypes: float64(2)
# memory usage: 1.2 KB

# %%
#因為索引是datetime的資料
weather_df.loc['2024-01-10':'2024-01-30']
weather_df.loc['2024-01']
weather_df.loc['2024']
# Out:
#                Tokyo    Taipei
# 2024-01-01  4.871864  4.303770
# 2024-01-02  0.343694  1.296325
# 2024-01-03  3.120858  4.179998
# 2024-01-04  3.338732  2.033667
# 2024-01-05  3.495731  0.094596
# 2024-01-06  3.216421  4.178185
# 2024-01-07  0.343869  0.887215
# 2024-01-08  3.031784  2.111864
# 2024-01-09  2.299117  3.929853
# 2024-01-10  0.015426  4.370589
# 2024-01-11  1.314682  0.841648
# 2024-01-12  2.641836  4.597620
# 2024-01-13  2.577909  3.489629
# 2024-01-14  3.801712  3.623012
# 2024-01-15  0.714803  4.187393
# 2024-01-16  0.002447  3.356910
# 2024-01-17  4.269184  4.375562
# 2024-01-18  4.488171  1.825987
# 2024-01-19  4.834710  4.644322
# 2024-01-20  0.952621  4.646455
# 2024-01-21  3.479473  1.943549
# 2024-01-22  3.346989  1.563825
# 2024-01-23  3.200919  2.217373
# 2024-01-24  4.843052  4.377144
# 2024-01-25  2.303692  4.230274
# 2024-01-26  3.687931  3.806294
# 2024-01-27  0.849879  2.040090
# 2024-01-28  4.496071  4.047426
# 2024-01-29  2.029275  3.187945
# 2024-01-30  0.869497  4.804783
# 2024-01-31  0.237283  4.352987
# 2024-02-01  4.714758  2.226033
# 2024-02-02  1.793708  2.460274
# 2024-02-03  1.875707  3.053249
# 2024-02-04  0.036283  2.511255
# 2024-02-05  3.613984  2.431316
# 2024-02-06  3.130242  4.588781
# 2024-02-07  3.327423  0.074336
# 2024-02-08  1.568659  0.151889
# 2024-02-09  1.360613  0.510693
# 2024-02-10  4.534306  1.158300
# 2024-02-11  2.610160  4.862634
# 2024-02-12  2.113981  4.363468
# 2024-02-13  4.922364  4.214815
# 2024-02-14  0.316567  2.303695
# 2024-02-15  3.926644  2.742303
# 2024-02-16  4.730266  1.814040
# 2024-02-17  1.094246  2.372535
# 2024-02-18  4.000303  2.807179
# 2024-02-19  2.431408  1.404295

# %%
import matplotlib.pyplot as plt

figure = plt.figure(figsize=(10,6))
axes = figure.add_subplot(1, 1, 1)
axes.plot(weather_df.index,weather_df['Tokyo'],label='Tokyo',linestyle='',marker='.')
axes.plot(weather_df.index,weather_df['Taipei'],label='Taipei',linestyle='',marker='.')

plt.show()
plt.close()

# %%
figure = plt.figure(figsize=(10,6))
axes = figure.add_subplot(1,1,1)
weather_df.plot(ax=axes,linestyle='',marker='.')
plt.show()
plt.close()

# %%
weather_df = pd.DataFrame(np.random.rand(10,2)*5,
                          index=pd.date_range(start="2024-01-01", periods=10),
                          columns=["Tokyo","Taipei"]
                          )

weather_df.loc['2024-01-01':'2024-01-07'].style.pipe(make_pretty)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 6
#       1 weather_df = pd.DataFrame(np.random.rand(10,2)*5,
#       2                           index=pd.date_range(start="2024-01-01", periods=10),
#       3                           columns=["Tokyo","Taipei"]
#       4                           )
# ----> 6 weather_df.loc['2024-01-01':'2024-01-07'].style.pipe()
#
# TypeError: Styler.pipe() missing 1 required positional argument: 'func'

# %%
weather_df = pd.DataFrame(np.random.rand(10,2)*5,
                          index=pd.date_range(start="2024-01-01", periods=10),
                          columns=["Tokyo","Taipei"]
                          )
def make_pretty(style):
    return style

s = weather_df.loc['2024-01-01':'2024-01-07'].style.pipe(make_pretty)
s
# Out:
# <style type="text/css">
# </style>
# <table id="T_343c8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_343c8_level0_col0" class="col_heading level0 col0" >Tokyo</th>
#       <th id="T_343c8_level0_col1" class="col_heading level0 col1" >Taipei</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_343c8_level0_row0" class="row_heading level0 row0" >2024-01-01 00:00:00</th>
#       <td id="T_343c8_row0_col0" class="data row0 col0" >1.587429</td>
#       <td id="T_343c8_row0_col1" class="data row0 col1" >3.280799</td>
#     </tr>
#     <tr>
#       <th id="T_343c8_level0_row1" class="row_heading level0 row1" >2024-01-02 00:00:00</th>
#       <td id="T_343c8_row1_col0" class="data row1 col0" >1.529502</td>
#       <td id="T_343c8_row1_col1" class="data row1 col1" >0.360055</td>
#     </tr>
#     <tr>
#       <th id="T_343c8_level0_row2" class="row_heading level0 row2" >2024-01-03 00:00:00</th>
#       <td id="T_343c8_row2_col0" class="data row2 col0" >4.634324</td>
#       <td id="T_343c8_row2_col1" class="data row2 col1" >1.532825</td>
#     </tr>
#     <tr>
#       <th id="T_343c8_level0_row3" class="row_heading level0 row3" >2024-01-04 00:00:00</th>
#       <td id="T_343c8_row3_col0" class="data row3 col0" >2.481238</td>
#       <td id="T_343c8_row3_col1" class="data row3 col1" >0.306322</td>
#     </tr>
#     <tr>
#       <th id="T_343c8_level0_row4" class="row_heading level0 row4" >2024-01-05 00:00:00</th>
#       <td id="T_343c8_row4_col0" class="data row4 col0" >3.894059</td>
#       <td id="T_343c8_row4_col1" class="data row4 col1" >2.532211</td>
#     </tr>
#     <tr>
#       <th id="T_343c8_level0_row5" class="row_heading level0 row5" >2024-01-06 00:00:00</th>
#       <td id="T_343c8_row5_col0" class="data row5 col0" >1.827124</td>
#       <td id="T_343c8_row5_col1" class="data row5 col1" >4.333722</td>
#     </tr>
#     <tr>
#       <th id="T_343c8_level0_row6" class="row_heading level0 row6" >2024-01-07 00:00:00</th>
#       <td id="T_343c8_row6_col0" class="data row6 col0" >3.389576</td>
#       <td id="T_343c8_row6_col1" class="data row6 col1" >2.891360</td>
#     </tr>
#   </tbody>
# </table>

# %%
weather_df = pd.DataFrame(np.random.rand(10,2)*5,
                          index=pd.date_range(start="2024-01-01", periods=10),
                          columns=["Tokyo","Taipei"]
                          )
def make_pretty(styler):
    styler.set_caption('天氣狀況')
    return styler

s = weather_df.loc['2024-01-01':'2024-01-07'].style.pipe(make_pretty)
s
# Out:
# <style type="text/css">
# </style>
# <table id="T_04dd1">
#   <caption>天氣狀況</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_04dd1_level0_col0" class="col_heading level0 col0" >Tokyo</th>
#       <th id="T_04dd1_level0_col1" class="col_heading level0 col1" >Taipei</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_04dd1_level0_row0" class="row_heading level0 row0" >2024-01-01 00:00:00</th>
#       <td id="T_04dd1_row0_col0" class="data row0 col0" >0.645475</td>
#       <td id="T_04dd1_row0_col1" class="data row0 col1" >0.745486</td>
#     </tr>
#     <tr>
#       <th id="T_04dd1_level0_row1" class="row_heading level0 row1" >2024-01-02 00:00:00</th>
#       <td id="T_04dd1_row1_col0" class="data row1 col0" >3.649159</td>
#       <td id="T_04dd1_row1_col1" class="data row1 col1" >1.470530</td>
#     </tr>
#     <tr>
#       <th id="T_04dd1_level0_row2" class="row_heading level0 row2" >2024-01-03 00:00:00</th>
#       <td id="T_04dd1_row2_col0" class="data row2 col0" >2.749639</td>
#       <td id="T_04dd1_row2_col1" class="data row2 col1" >2.042186</td>
#     </tr>
#     <tr>
#       <th id="T_04dd1_level0_row3" class="row_heading level0 row3" >2024-01-04 00:00:00</th>
#       <td id="T_04dd1_row3_col0" class="data row3 col0" >1.133239</td>
#       <td id="T_04dd1_row3_col1" class="data row3 col1" >4.713972</td>
#     </tr>
#     <tr>
#       <th id="T_04dd1_level0_row4" class="row_heading level0 row4" >2024-01-05 00:00:00</th>
#       <td id="T_04dd1_row4_col0" class="data row4 col0" >3.857434</td>
#       <td id="T_04dd1_row4_col1" class="data row4 col1" >1.703170</td>
#     </tr>
#     <tr>
#       <th id="T_04dd1_level0_row5" class="row_heading level0 row5" >2024-01-06 00:00:00</th>
#       <td id="T_04dd1_row5_col0" class="data row5 col0" >4.865411</td>
#       <td id="T_04dd1_row5_col1" class="data row5 col1" >4.361460</td>
#     </tr>
#     <tr>
#       <th id="T_04dd1_level0_row6" class="row_heading level0 row6" >2024-01-07 00:00:00</th>
#       <td id="T_04dd1_row6_col0" class="data row6 col0" >1.783509</td>
#       <td id="T_04dd1_row6_col1" class="data row6 col1" >2.061026</td>
#     </tr>
#   </tbody>
# </table>

# %%
weather_df = pd.DataFrame(np.random.rand(10,2)*5,
                          index=pd.date_range(start="2024-01-01", periods=10),
                          columns=["Tokyo","Taipei"]
                          )
def rain_condition(v):
    if v > 1.75:
        return'乾燥'
    elif v < 2.75:
        return '小雨'
    else:
        return'大雨'
    
def make_pretty(styler):
    styler.set_caption('天氣狀況')
    styler.format(rain_condition)
    return styler

s = weather_df.loc['2024-01-01':'2024-01-07'].style.pipe(make_pretty)
s
# Out:
# <style type="text/css">
# </style>
# <table id="T_9ea77">
#   <caption>天氣狀況</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9ea77_level0_col0" class="col_heading level0 col0" >Tokyo</th>
#       <th id="T_9ea77_level0_col1" class="col_heading level0 col1" >Taipei</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9ea77_level0_row0" class="row_heading level0 row0" >2024-01-01 00:00:00</th>
#       <td id="T_9ea77_row0_col0" class="data row0 col0" >小雨</td>
#       <td id="T_9ea77_row0_col1" class="data row0 col1" >小雨</td>
#     </tr>
#     <tr>
#       <th id="T_9ea77_level0_row1" class="row_heading level0 row1" >2024-01-02 00:00:00</th>
#       <td id="T_9ea77_row1_col0" class="data row1 col0" >乾燥</td>
#       <td id="T_9ea77_row1_col1" class="data row1 col1" >乾燥</td>
#     </tr>
#     <tr>
#       <th id="T_9ea77_level0_row2" class="row_heading level0 row2" >2024-01-03 00:00:00</th>
#       <td id="T_9ea77_row2_col0" class="data row2 col0" >乾燥</td>
#       <td id="T_9ea77_row2_col1" class="data row2 col1" >乾燥</td>
#     </tr>
#     <tr>
#       <th id="T_9ea77_level0_row3" class="row_heading level0 row3" >2024-01-04 00:00:00</th>
#       <td id="T_9ea77_row3_col0" class="data row3 col0" >乾燥</td>
#       <td id="T_9ea77_row3_col1" class="data row3 col1" >乾燥</td>
#     </tr>
#     <tr>
#       <th id="T_9ea77_level0_row4" class="row_heading level0 row4" >2024-01-05 00:00:00</th>
#       <td id="T_9ea77_row4_col0" class="data row4 col0" >乾燥</td>
#       <td id="T_9ea77_row4_col1" class="data row4 col1" >乾燥</td>
#     </tr>
#     <tr>
#       <th id="T_9ea77_level0_row5" class="row_heading level0 row5" >2024-01-06 00:00:00</th>
#       <td id="T_9ea77_row5_col0" class="data row5 col0" >乾燥</td>
#       <td id="T_9ea77_row5_col1" class="data row5 col1" >乾燥</td>
#     </tr>
#     <tr>
#       <th id="T_9ea77_level0_row6" class="row_heading level0 row6" >2024-01-07 00:00:00</th>
#       <td id="T_9ea77_row6_col0" class="data row6 col0" >乾燥</td>
#       <td id="T_9ea77_row6_col1" class="data row6 col1" >乾燥</td>
#     </tr>
#   </tbody>
# </table>

# %%
weather_df = pd.DataFrame(np.random.rand(10,2)*5,
                          index=pd.date_range(start="2024-01-01", periods=10),
                          columns=["Tokyo","Taipei"]
                          )
def rain_condition(v):
    if v > 1.75:
        return'乾燥'
    elif v < 2.75:
        return '小雨'
    else:
        return'大雨'
    
def make_pretty(styler):
    styler.set_caption('天氣狀況')
    styler.format(rain_condition)
    styler.format_index(formatter=lambda v:v.strftime('%Y-%m-%A'))
    return styler

s = weather_df.loc['2024-01-01':'2024-01-07'].style.pipe(make_pretty)
s
# Out:
# <style type="text/css">
# </style>
# <table id="T_89fde">
#   <caption>天氣狀況</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_89fde_level0_col0" class="col_heading level0 col0" >Tokyo</th>
#       <th id="T_89fde_level0_col1" class="col_heading level0 col1" >Taipei</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_89fde_level0_row0" class="row_heading level0 row0" >2024-01-Monday</th>
#       <td id="T_89fde_row0_col0" class="data row0 col0" >乾燥</td>
#       <td id="T_89fde_row0_col1" class="data row0 col1" >乾燥</td>
#     </tr>
#     <tr>
#       <th id="T_89fde_level0_row1" class="row_heading level0 row1" >2024-01-Tuesday</th>
#       <td id="T_89fde_row1_col0" class="data row1 col0" >乾燥</td>
#       <td id="T_89fde_row1_col1" class="data row1 col1" >小雨</td>
#     </tr>
#     <tr>
#       <th id="T_89fde_level0_row2" class="row_heading level0 row2" >2024-01-Wednesday</th>
#       <td id="T_89fde_row2_col0" class="data row2 col0" >乾燥</td>
#       <td id="T_89fde_row2_col1" class="data row2 col1" >乾燥</td>
#     </tr>
#     <tr>
#       <th id="T_89fde_level0_row3" class="row_heading level0 row3" >2024-01-Thursday</th>
#       <td id="T_89fde_row3_col0" class="data row3 col0" >乾燥</td>
#       <td id="T_89fde_row3_col1" class="data row3 col1" >乾燥</td>
#     </tr>
#     <tr>
#       <th id="T_89fde_level0_row4" class="row_heading level0 row4" >2024-01-Friday</th>
#       <td id="T_89fde_row4_col0" class="data row4 col0" >小雨</td>
#       <td id="T_89fde_row4_col1" class="data row4 col1" >小雨</td>
#     </tr>
#     <tr>
#       <th id="T_89fde_level0_row5" class="row_heading level0 row5" >2024-01-Saturday</th>
#       <td id="T_89fde_row5_col0" class="data row5 col0" >乾燥</td>
#       <td id="T_89fde_row5_col1" class="data row5 col1" >乾燥</td>
#     </tr>
#     <tr>
#       <th id="T_89fde_level0_row6" class="row_heading level0 row6" >2024-01-Sunday</th>
#       <td id="T_89fde_row6_col0" class="data row6 col0" >乾燥</td>
#       <td id="T_89fde_row6_col1" class="data row6 col1" >乾燥</td>
#     </tr>
#   </tbody>
# </table>

# %%
weather_df = pd.DataFrame(np.random.rand(10,2)*5,
                          index=pd.date_range(start="2024-01-01", periods=10),
                          columns=["Tokyo","Taipei"]
                          )
def rain_condition(v):
    if v > 1.75:
        return'乾燥'
    elif v < 2.75:
        return '小雨'
    else:
        return'大雨'
    
def make_pretty(styler):
    styler.set_caption('天氣狀況')
    styler.format(rain_condition)
    styler.format_index(formatter=lambda v:v.strftime('%Y-%m-%A'))
    styler.background_gradient(axis=None,vmin=1,vmax=5)
    return styler

s = weather_df.loc['2024-01-01':'2024-01-07'].style.pipe(make_pretty)
s
# Out:
# <style type="text/css">
# #T_90bb7_row0_col0 {
#   background-color: #60a1ca;
#   color: #f1f1f1;
# }
# #T_90bb7_row0_col1 {
#   background-color: #046198;
#   color: #f1f1f1;
# }
# #T_90bb7_row1_col0 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_90bb7_row1_col1 {
#   background-color: #2786bb;
#   color: #f1f1f1;
# }
# #T_90bb7_row2_col0 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_90bb7_row2_col1 {
#   background-color: #045c90;
#   color: #f1f1f1;
# }
# #T_90bb7_row3_col0, #T_90bb7_row4_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_90bb7_row3_col1 {
#   background-color: #88b1d4;
#   color: #000000;
# }
# #T_90bb7_row4_col0 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_90bb7_row5_col0 {
#   background-color: #034c78;
#   color: #f1f1f1;
# }
# #T_90bb7_row5_col1 {
#   background-color: #197db7;
#   color: #f1f1f1;
# }
# #T_90bb7_row6_col0 {
#   background-color: #89b1d4;
#   color: #000000;
# }
# #T_90bb7_row6_col1 {
#   background-color: #056aa6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_90bb7">
#   <caption>天氣狀況</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_90bb7_level0_col0" class="col_heading level0 col0" >Tokyo</th>
#       <th id="T_90bb7_level0_col1" class="col_heading level0 col1" >Taipei</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_90bb7_level0_row0" class="row_heading level0 row0" >2024-01-Monday</th>
#       <td id="T_90bb7_row0_col0" class="data row0 col0" >乾燥</td>
#       <td id="T_90bb7_row0_col1" class="data row0 col1" >乾燥</td>
#     </tr>
#     <tr>
#       <th id="T_90bb7_level0_row1" class="row_heading level0 row1" >2024-01-Tuesday</th>
#       <td id="T_90bb7_row1_col0" class="data row1 col0" >乾燥</td>
#       <td id="T_90bb7_row1_col1" class="data row1 col1" >乾燥</td>
#     </tr>
#     <tr>
#       <th id="T_90bb7_level0_row2" class="row_heading level0 row2" >2024-01-Wednesday</th>
#       <td id="T_90bb7_row2_col0" class="data row2 col0" >乾燥</td>
#       <td id="T_90bb7_row2_col1" class="data row2 col1" >乾燥</td>
#     </tr>
#     <tr>
#       <th id="T_90bb7_level0_row3" class="row_heading level0 row3" >2024-01-Thursday</th>
#       <td id="T_90bb7_row3_col0" class="data row3 col0" >小雨</td>
#       <td id="T_90bb7_row3_col1" class="data row3 col1" >乾燥</td>
#     </tr>
#     <tr>
#       <th id="T_90bb7_level0_row4" class="row_heading level0 row4" >2024-01-Friday</th>
#       <td id="T_90bb7_row4_col0" class="data row4 col0" >小雨</td>
#       <td id="T_90bb7_row4_col1" class="data row4 col1" >小雨</td>
#     </tr>
#     <tr>
#       <th id="T_90bb7_level0_row5" class="row_heading level0 row5" >2024-01-Saturday</th>
#       <td id="T_90bb7_row5_col0" class="data row5 col0" >乾燥</td>
#       <td id="T_90bb7_row5_col1" class="data row5 col1" >乾燥</td>
#     </tr>
#     <tr>
#       <th id="T_90bb7_level0_row6" class="row_heading level0 row6" >2024-01-Sunday</th>
#       <td id="T_90bb7_row6_col0" class="data row6 col0" >乾燥</td>
#       <td id="T_90bb7_row6_col1" class="data row6 col1" >乾燥</td>
#     </tr>
#   </tbody>
# </table>

# %%
weather_df = pd.DataFrame(np.random.rand(10,2)*5,
                          index=pd.date_range(start="2024-01-01", periods=10),
                          columns=["Tokyo","Taipei"]
                          )
display(weather_df)
def rain_condition(v):
    if v > 1.75:
        return'乾燥'
    elif v < 2.75:
        return '小雨'
    else:
        return'大雨'
    
def make_pretty(styler):
    styler.set_caption('天氣狀況')
    styler.format(rain_condition)
    styler.format_index(formatter=lambda v:v.strftime('%Y-%m-%A'))
    styler.background_gradient(axis=None,vmin=1,vmax=5, cmap="PuBuGn")
    return styler

s = weather_df.loc['2024-01-01':'2024-01-07'].style.pipe(make_pretty)
s
# Out:
#                Tokyo    Taipei
# 2024-01-01  2.651752  2.531634
# 2024-01-02  1.155392  3.137556
# 2024-01-03  4.097559  3.697618
# 2024-01-04  0.108282  2.972138
# 2024-01-05  3.628428  1.686590
# 2024-01-06  1.608959  2.386714
# 2024-01-07  4.447229  1.967454
# 2024-01-08  1.552506  2.403818
# 2024-01-09  1.892687  3.767227
# 2024-01-10  1.224097  4.779628
# <style type="text/css">
# #T_70d31_row0_col0 {
#   background-color: #93b7d7;
#   color: #000000;
# }
# #T_70d31_row0_col1 {
#   background-color: #a1bcda;
#   color: #000000;
# }
# #T_70d31_row1_col0 {
#   background-color: #faf1f8;
#   color: #000000;
# }
# #T_70d31_row1_col1 {
#   background-color: #5aa2cb;
#   color: #f1f1f1;
# }
# #T_70d31_row2_col0 {
#   background-color: #027d80;
#   color: #f1f1f1;
# }
# #T_70d31_row2_col1 {
#   background-color: #218aab;
#   color: #f1f1f1;
# }
# #T_70d31_row3_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_70d31_row3_col1 {
#   background-color: #6aaad0;
#   color: #f1f1f1;
# }
# #T_70d31_row4_col0 {
#   background-color: #288cb1;
#   color: #f1f1f1;
# }
# #T_70d31_row4_col1 {
#   background-color: #e2dced;
#   color: #000000;
# }
# #T_70d31_row5_col0 {
#   background-color: #e7dfee;
#   color: #000000;
# }
# #T_70d31_row5_col1 {
#   background-color: #b0c2de;
#   color: #000000;
# }
# #T_70d31_row6_col0 {
#   background-color: #016e5e;
#   color: #f1f1f1;
# }
# #T_70d31_row6_col1 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# </style>
# <table id="T_70d31">
#   <caption>天氣狀況</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_70d31_level0_col0" class="col_heading level0 col0" >Tokyo</th>
#       <th id="T_70d31_level0_col1" class="col_heading level0 col1" >Taipei</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_70d31_level0_row0" class="row_heading level0 row0" >2024-01-Monday</th>
#       <td id="T_70d31_row0_col0" class="data row0 col0" >乾燥</td>
#       <td id="T_70d31_row0_col1" class="data row0 col1" >乾燥</td>
#     </tr>
#     <tr>
#       <th id="T_70d31_level0_row1" class="row_heading level0 row1" >2024-01-Tuesday</th>
#       <td id="T_70d31_row1_col0" class="data row1 col0" >小雨</td>
#       <td id="T_70d31_row1_col1" class="data row1 col1" >乾燥</td>
#     </tr>
#     <tr>
#       <th id="T_70d31_level0_row2" class="row_heading level0 row2" >2024-01-Wednesday</th>
#       <td id="T_70d31_row2_col0" class="data row2 col0" >乾燥</td>
#       <td id="T_70d31_row2_col1" class="data row2 col1" >乾燥</td>
#     </tr>
#     <tr>
#       <th id="T_70d31_level0_row3" class="row_heading level0 row3" >2024-01-Thursday</th>
#       <td id="T_70d31_row3_col0" class="data row3 col0" >小雨</td>
#       <td id="T_70d31_row3_col1" class="data row3 col1" >乾燥</td>
#     </tr>
#     <tr>
#       <th id="T_70d31_level0_row4" class="row_heading level0 row4" >2024-01-Friday</th>
#       <td id="T_70d31_row4_col0" class="data row4 col0" >乾燥</td>
#       <td id="T_70d31_row4_col1" class="data row4 col1" >小雨</td>
#     </tr>
#     <tr>
#       <th id="T_70d31_level0_row5" class="row_heading level0 row5" >2024-01-Saturday</th>
#       <td id="T_70d31_row5_col0" class="data row5 col0" >小雨</td>
#       <td id="T_70d31_row5_col1" class="data row5 col1" >乾燥</td>
#     </tr>
#     <tr>
#       <th id="T_70d31_level0_row6" class="row_heading level0 row6" >2024-01-Sunday</th>
#       <td id="T_70d31_row6_col0" class="data row6 col0" >乾燥</td>
#       <td id="T_70d31_row6_col1" class="data row6 col1" >乾燥</td>
#     </tr>
#   </tbody>
# </table>

# %%
np.random.seed(1234)
weather_df = pd.DataFrame(np.random.rand(10,2)*5,
                          index=pd.date_range(start="2024-01-01", periods=10),
                          columns=["Tokyo","Taipei"]
                          )
display(weather_df)
def rain_condition(v):
    if v < 1.75:
        return "乾燥"
    elif v < 2.75:
        return "小雨"
    else:
        return "大雨"

def make_pretty(styler):
    styler.set_caption("天氣狀況")
    styler.format(rain_condition)
    styler.format_index(formatter=lambda v:v.strftime("%Y/%m/%d %A"))
    styler.background_gradient(axis=None,vmin=1,vmax=5,cmap="PuBuGn")
    return styler

s = weather_df.loc['2024-01-01':'2024-01-07'].style.pipe(make_pretty)
s.to_excel('weather_condition.xlsx')
# Out:
#                Tokyo    Taipei
# 2024-01-01  0.957597  3.110544
# 2024-01-02  2.188639  3.926793
# 2024-01-03  3.899879  1.362963
# 2024-01-04  1.382321  4.009361
# 2024-01-05  4.790697  4.379663
# 2024-01-06  1.789086  2.504976
# 2024-01-07  3.417315  3.563510
# 2024-01-08  1.851254  2.805981
# 2024-01-09  2.515416  0.068842
# 2024-01-10  3.864133  4.413206
