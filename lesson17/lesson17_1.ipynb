# %% [markdown]
# ### https://www.perplexity.ai/search/541099c9-ea3f-4aaa-98b2-53af4156f3cc

# %% [markdown]
# ## 需要安裝jinja2套件

# %%
#styler.format()
#style.format_index()
#style.relabel_index
import pandas as pd
import numpy as np

df = pd.DataFrame({
    "strings": ["Adam", "Mike"],
    "ints": [1, 3],
    "floats": [1.123, 1000.23]
})
type(df.style)

display(df)
s = df.style\
.format(precision=3, thousands=",", decimal='.')\
.format_index(str.upper,axis=1)\
.relabel_index(["列1","列2"])

s
# Out:
#   strings  ints    floats
# 0    Adam     1     1.123
# 1    Mike     3  1000.230
# <style type="text/css">
# </style>
# <table id="T_91248">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_91248_level0_col0" class="col_heading level0 col0" >STRINGS</th>
#       <th id="T_91248_level0_col1" class="col_heading level0 col1" >INTS</th>
#       <th id="T_91248_level0_col2" class="col_heading level0 col2" >FLOATS</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_91248_level0_row0" class="row_heading level0 row0" >列1</th>
#       <td id="T_91248_row0_col0" class="data row0 col0" >Adam</td>
#       <td id="T_91248_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_91248_row0_col2" class="data row0 col2" >1.123</td>
#     </tr>
#     <tr>
#       <th id="T_91248_level0_row1" class="row_heading level0 row1" >列2</th>
#       <td id="T_91248_row1_col0" class="data row1 col0" >Mike</td>
#       <td id="T_91248_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_91248_row1_col2" class="data row1 col2" >1,000.230</td>
#     </tr>
#   </tbody>
# </table>

# %%
weather_df = pd.DataFrame(np.random.rand(50,2)*5,
                          index=pd.date_range(start="2024-01-01", periods=50),
                          columns=["Tokyo","Taipei"]
                          )
weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 50 entries, 2024-01-01 to 2024-02-19
# Freq: D
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Tokyo   50 non-null     float64
#  1   Taipei  50 non-null     float64
# dtypes: float64(2)
# memory usage: 1.2 KB

# %%
#因為索引是datetime的資料
weather_df.loc['2024-01-10':'2024-01-30']
weather_df.loc['2024-01']
weather_df.loc['2024']
# Out:
#                Tokyo    Taipei
# 2024-01-01  1.244265  4.479473
# 2024-01-02  4.836015  2.355672
# 2024-01-03  0.494374  0.497678
# 2024-01-04  3.554227  4.030443
# 2024-01-05  4.602952  3.686497
# 2024-01-06  4.760256  0.835820
# 2024-01-07  2.322036  1.440659
# 2024-01-08  4.171608  0.044447
# 2024-01-09  0.784520  3.436641
# 2024-01-10  0.859213  4.345796
# 2024-01-11  0.426187  4.689212
# 2024-01-12  2.911526  0.068423
# 2024-01-13  0.691604  1.636230
# 2024-01-14  0.309202  3.172088
# 2024-01-15  0.156306  1.490423
# 2024-01-16  1.631893  3.199608
# 2024-01-17  1.681049  4.445892
# 2024-01-18  0.180995  1.147278
# 2024-01-19  2.566857  3.316205
# 2024-01-20  3.891955  3.178359
# 2024-01-21  3.866919  0.785076
# 2024-01-22  3.082180  0.286782
# 2024-01-23  3.623875  4.042821
# 2024-01-24  0.243397  3.470355
# 2024-01-25  1.114490  4.912600
# 2024-01-26  2.174826  0.076248
# 2024-01-27  3.675444  1.703385
# 2024-01-28  0.795476  0.266691
# 2024-01-29  2.267149  2.482991
# 2024-01-30  4.822329  4.399133
# 2024-01-31  0.261826  1.458208
# 2024-02-01  0.038664  4.646829
# 2024-02-02  2.004496  1.800381
# 2024-02-03  4.260932  2.671753
# 2024-02-04  2.338406  1.873138
# 2024-02-05  3.510165  2.736604
# 2024-02-06  3.052234  4.005488
# 2024-02-07  2.251359  0.691938
# 2024-02-08  1.105860  1.162970
# 2024-02-09  2.648454  3.842600
# 2024-02-10  4.144929  4.180322
# 2024-02-11  2.224671  1.246112
# 2024-02-12  3.007485  2.189849
# 2024-02-13  4.328672  3.534853
# 2024-02-14  2.000269  2.728416
# 2024-02-15  4.792216  2.637427
# 2024-02-16  1.510509  2.301174
# 2024-02-17  1.695879  2.817246
# 2024-02-18  2.235536  1.498275
# 2024-02-19  0.018409  0.975091

# %%
import matplotlib.pyplot as plt

figure = plt.figure(figsize=(10,6))
axes = figure.add_subplot(1, 1, 1)
axes.plot(weather_df.index,weather_df['Tokyo'],label='Tokyo',linestyle='',marker='.')
axes.plot(weather_df.index,weather_df['Taipei'],label='Taipei',linestyle='',marker='.')

plt.show()
plt.close()

# %%
figure = plt.figure(figsize=(10,6))
axes = figure.add_subplot(1,1,1)
weather_df.plot(ax=axes,linestyle='',marker='.')
plt.show()
plt.close()

# %%
weather_df = pd.DataFrame(np.random.rand(10,2)*5,
                          index=pd.date_range(start="2024-01-01", periods=10),
                          columns=["Tokyo","Taipei"]
                          )

weather_df.loc['2024-01-01':'2024-01-07'].style.pipe(make_pretty)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 6
#       1 weather_df = pd.DataFrame(np.random.rand(10,2)*5,
#       2                           index=pd.date_range(start="2024-01-01", periods=10),
#       3                           columns=["Tokyo","Taipei"]
#       4                           )
# ----> 6 weather_df.loc['2024-01-01':'2024-01-07'].style.pipe(make_pretty)
#
# NameError: name 'make_pretty' is not defined

# %%
weather_df = pd.DataFrame(np.random.rand(10,2)*5,
                          index=pd.date_range(start="2024-01-01", periods=10),
                          columns=["Tokyo","Taipei"]
                          )
def make_pretty(style):
    return style

s = weather_df.loc['2024-01-01':'2024-01-07'].style.pipe(make_pretty)
s
# Out:
# <style type="text/css">
# </style>
# <table id="T_343c8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_343c8_level0_col0" class="col_heading level0 col0" >Tokyo</th>
#       <th id="T_343c8_level0_col1" class="col_heading level0 col1" >Taipei</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_343c8_level0_row0" class="row_heading level0 row0" >2024-01-01 00:00:00</th>
#       <td id="T_343c8_row0_col0" class="data row0 col0" >1.587429</td>
#       <td id="T_343c8_row0_col1" class="data row0 col1" >3.280799</td>
#     </tr>
#     <tr>
#       <th id="T_343c8_level0_row1" class="row_heading level0 row1" >2024-01-02 00:00:00</th>
#       <td id="T_343c8_row1_col0" class="data row1 col0" >1.529502</td>
#       <td id="T_343c8_row1_col1" class="data row1 col1" >0.360055</td>
#     </tr>
#     <tr>
#       <th id="T_343c8_level0_row2" class="row_heading level0 row2" >2024-01-03 00:00:00</th>
#       <td id="T_343c8_row2_col0" class="data row2 col0" >4.634324</td>
#       <td id="T_343c8_row2_col1" class="data row2 col1" >1.532825</td>
#     </tr>
#     <tr>
#       <th id="T_343c8_level0_row3" class="row_heading level0 row3" >2024-01-04 00:00:00</th>
#       <td id="T_343c8_row3_col0" class="data row3 col0" >2.481238</td>
#       <td id="T_343c8_row3_col1" class="data row3 col1" >0.306322</td>
#     </tr>
#     <tr>
#       <th id="T_343c8_level0_row4" class="row_heading level0 row4" >2024-01-05 00:00:00</th>
#       <td id="T_343c8_row4_col0" class="data row4 col0" >3.894059</td>
#       <td id="T_343c8_row4_col1" class="data row4 col1" >2.532211</td>
#     </tr>
#     <tr>
#       <th id="T_343c8_level0_row5" class="row_heading level0 row5" >2024-01-06 00:00:00</th>
#       <td id="T_343c8_row5_col0" class="data row5 col0" >1.827124</td>
#       <td id="T_343c8_row5_col1" class="data row5 col1" >4.333722</td>
#     </tr>
#     <tr>
#       <th id="T_343c8_level0_row6" class="row_heading level0 row6" >2024-01-07 00:00:00</th>
#       <td id="T_343c8_row6_col0" class="data row6 col0" >3.389576</td>
#       <td id="T_343c8_row6_col1" class="data row6 col1" >2.891360</td>
#     </tr>
#   </tbody>
# </table>

# %%
weather_df = pd.DataFrame(np.random.rand(10,2)*5,
                          index=pd.date_range(start="2024-01-01", periods=10),
                          columns=["Tokyo","Taipei"]
                          )
def make_pretty(styler):
    styler.set_caption('天氣狀況')
    return styler

s = weather_df.loc['2024-01-01':'2024-01-07'].style.pipe(make_pretty)
s
# Out:
# <style type="text/css">
# </style>
# <table id="T_04dd1">
#   <caption>天氣狀況</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_04dd1_level0_col0" class="col_heading level0 col0" >Tokyo</th>
#       <th id="T_04dd1_level0_col1" class="col_heading level0 col1" >Taipei</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_04dd1_level0_row0" class="row_heading level0 row0" >2024-01-01 00:00:00</th>
#       <td id="T_04dd1_row0_col0" class="data row0 col0" >0.645475</td>
#       <td id="T_04dd1_row0_col1" class="data row0 col1" >0.745486</td>
#     </tr>
#     <tr>
#       <th id="T_04dd1_level0_row1" class="row_heading level0 row1" >2024-01-02 00:00:00</th>
#       <td id="T_04dd1_row1_col0" class="data row1 col0" >3.649159</td>
#       <td id="T_04dd1_row1_col1" class="data row1 col1" >1.470530</td>
#     </tr>
#     <tr>
#       <th id="T_04dd1_level0_row2" class="row_heading level0 row2" >2024-01-03 00:00:00</th>
#       <td id="T_04dd1_row2_col0" class="data row2 col0" >2.749639</td>
#       <td id="T_04dd1_row2_col1" class="data row2 col1" >2.042186</td>
#     </tr>
#     <tr>
#       <th id="T_04dd1_level0_row3" class="row_heading level0 row3" >2024-01-04 00:00:00</th>
#       <td id="T_04dd1_row3_col0" class="data row3 col0" >1.133239</td>
#       <td id="T_04dd1_row3_col1" class="data row3 col1" >4.713972</td>
#     </tr>
#     <tr>
#       <th id="T_04dd1_level0_row4" class="row_heading level0 row4" >2024-01-05 00:00:00</th>
#       <td id="T_04dd1_row4_col0" class="data row4 col0" >3.857434</td>
#       <td id="T_04dd1_row4_col1" class="data row4 col1" >1.703170</td>
#     </tr>
#     <tr>
#       <th id="T_04dd1_level0_row5" class="row_heading level0 row5" >2024-01-06 00:00:00</th>
#       <td id="T_04dd1_row5_col0" class="data row5 col0" >4.865411</td>
#       <td id="T_04dd1_row5_col1" class="data row5 col1" >4.361460</td>
#     </tr>
#     <tr>
#       <th id="T_04dd1_level0_row6" class="row_heading level0 row6" >2024-01-07 00:00:00</th>
#       <td id="T_04dd1_row6_col0" class="data row6 col0" >1.783509</td>
#       <td id="T_04dd1_row6_col1" class="data row6 col1" >2.061026</td>
#     </tr>
#   </tbody>
# </table>

# %%
weather_df = pd.DataFrame(np.random.rand(10,2)*5,
                          index=pd.date_range(start="2024-01-01", periods=10),
                          columns=["Tokyo","Taipei"]
                          )
def rain_condition(v):
    if v > 1.75:
        return'乾燥'
    elif v < 2.75:
        return '小雨'
    else:
        return'大雨'
    
def make_pretty(styler):
    styler.set_caption('天氣狀況')
    styler.format(rain_condition)
    return styler

s = weather_df.loc['2024-01-01':'2024-01-07'].style.pipe(make_pretty)
s
# Out:
# <style type="text/css">
# </style>
# <table id="T_9ea77">
#   <caption>天氣狀況</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9ea77_level0_col0" class="col_heading level0 col0" >Tokyo</th>
#       <th id="T_9ea77_level0_col1" class="col_heading level0 col1" >Taipei</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9ea77_level0_row0" class="row_heading level0 row0" >2024-01-01 00:00:00</th>
#       <td id="T_9ea77_row0_col0" class="data row0 col0" >小雨</td>
#       <td id="T_9ea77_row0_col1" class="data row0 col1" >小雨</td>
#     </tr>
#     <tr>
#       <th id="T_9ea77_level0_row1" class="row_heading level0 row1" >2024-01-02 00:00:00</th>
#       <td id="T_9ea77_row1_col0" class="data row1 col0" >乾燥</td>
#       <td id="T_9ea77_row1_col1" class="data row1 col1" >乾燥</td>
#     </tr>
#     <tr>
#       <th id="T_9ea77_level0_row2" class="row_heading level0 row2" >2024-01-03 00:00:00</th>
#       <td id="T_9ea77_row2_col0" class="data row2 col0" >乾燥</td>
#       <td id="T_9ea77_row2_col1" class="data row2 col1" >乾燥</td>
#     </tr>
#     <tr>
#       <th id="T_9ea77_level0_row3" class="row_heading level0 row3" >2024-01-04 00:00:00</th>
#       <td id="T_9ea77_row3_col0" class="data row3 col0" >乾燥</td>
#       <td id="T_9ea77_row3_col1" class="data row3 col1" >乾燥</td>
#     </tr>
#     <tr>
#       <th id="T_9ea77_level0_row4" class="row_heading level0 row4" >2024-01-05 00:00:00</th>
#       <td id="T_9ea77_row4_col0" class="data row4 col0" >乾燥</td>
#       <td id="T_9ea77_row4_col1" class="data row4 col1" >乾燥</td>
#     </tr>
#     <tr>
#       <th id="T_9ea77_level0_row5" class="row_heading level0 row5" >2024-01-06 00:00:00</th>
#       <td id="T_9ea77_row5_col0" class="data row5 col0" >乾燥</td>
#       <td id="T_9ea77_row5_col1" class="data row5 col1" >乾燥</td>
#     </tr>
#     <tr>
#       <th id="T_9ea77_level0_row6" class="row_heading level0 row6" >2024-01-07 00:00:00</th>
#       <td id="T_9ea77_row6_col0" class="data row6 col0" >乾燥</td>
#       <td id="T_9ea77_row6_col1" class="data row6 col1" >乾燥</td>
#     </tr>
#   </tbody>
# </table>

# %%
weather_df = pd.DataFrame(np.random.rand(10,2)*5,
                          index=pd.date_range(start="2024-01-01", periods=10),
                          columns=["Tokyo","Taipei"]
                          )
def rain_condition(v):
    if v > 1.75:
        return'乾燥'
    elif v < 2.75:
        return '小雨'
    else:
        return'大雨'
    
def make_pretty(styler):
    styler.set_caption('天氣狀況')
    styler.format(rain_condition)
    styler.format_index(formatter=lambda v:v.strftime('%Y-%m-%A')) # styler.format_index(formatter=lambda v:v.strftime('%Y%m/%A'))
    return styler

s = weather_df.loc['2024-01-01':'2024-01-07'].style.pipe(make_pretty)
s
# Out:
# <style type="text/css">
# </style>
# <table id="T_0c100">
#   <caption>天氣狀況</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0c100_level0_col0" class="col_heading level0 col0" >Tokyo</th>
#       <th id="T_0c100_level0_col1" class="col_heading level0 col1" >Taipei</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0c100_level0_row0" class="row_heading level0 row0" >2024-01-Monday</th>
#       <td id="T_0c100_row0_col0" class="data row0 col0" >小雨</td>
#       <td id="T_0c100_row0_col1" class="data row0 col1" >乾燥</td>
#     </tr>
#     <tr>
#       <th id="T_0c100_level0_row1" class="row_heading level0 row1" >2024-01-Tuesday</th>
#       <td id="T_0c100_row1_col0" class="data row1 col0" >小雨</td>
#       <td id="T_0c100_row1_col1" class="data row1 col1" >小雨</td>
#     </tr>
#     <tr>
#       <th id="T_0c100_level0_row2" class="row_heading level0 row2" >2024-01-Wednesday</th>
#       <td id="T_0c100_row2_col0" class="data row2 col0" >乾燥</td>
#       <td id="T_0c100_row2_col1" class="data row2 col1" >乾燥</td>
#     </tr>
#     <tr>
#       <th id="T_0c100_level0_row3" class="row_heading level0 row3" >2024-01-Thursday</th>
#       <td id="T_0c100_row3_col0" class="data row3 col0" >乾燥</td>
#       <td id="T_0c100_row3_col1" class="data row3 col1" >乾燥</td>
#     </tr>
#     <tr>
#       <th id="T_0c100_level0_row4" class="row_heading level0 row4" >2024-01-Friday</th>
#       <td id="T_0c100_row4_col0" class="data row4 col0" >乾燥</td>
#       <td id="T_0c100_row4_col1" class="data row4 col1" >乾燥</td>
#     </tr>
#     <tr>
#       <th id="T_0c100_level0_row5" class="row_heading level0 row5" >2024-01-Saturday</th>
#       <td id="T_0c100_row5_col0" class="data row5 col0" >小雨</td>
#       <td id="T_0c100_row5_col1" class="data row5 col1" >乾燥</td>
#     </tr>
#     <tr>
#       <th id="T_0c100_level0_row6" class="row_heading level0 row6" >2024-01-Sunday</th>
#       <td id="T_0c100_row6_col0" class="data row6 col0" >乾燥</td>
#       <td id="T_0c100_row6_col1" class="data row6 col1" >乾燥</td>
#     </tr>
#   </tbody>
# </table>

# %%
weather_df = pd.DataFrame(np.random.rand(10,2)*5,
                          index=pd.date_range(start="2024-01-01", periods=10),
                          columns=["Tokyo","Taipei"]
                          )
def rain_condition(v):
    if v > 1.75:
        return'乾燥'
    elif v < 2.75:
        return '小雨'
    else:
        return'大雨'
    
def make_pretty(styler):
    styler.set_caption('天氣狀況')
    styler.format(rain_condition)
    styler.format_index(formatter=lambda v:v.strftime('%Y-%m-%A'))
    styler.background_gradient(axis=None,vmin=1,vmax=5)
    return styler

s = weather_df.loc['2024-01-01':'2024-01-07'].style.pipe(make_pretty)
s
# Out:
# <style type="text/css">
# #T_70c32_row0_col0 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_70c32_row0_col1 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_70c32_row1_col0 {
#   background-color: #4697c4;
#   color: #f1f1f1;
# }
# #T_70c32_row1_col1 {
#   background-color: #056aa6;
#   color: #f1f1f1;
# }
# #T_70c32_row2_col0 {
#   background-color: #046299;
#   color: #f1f1f1;
# }
# #T_70c32_row2_col1 {
#   background-color: #03466e;
#   color: #f1f1f1;
# }
# #T_70c32_row3_col0 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_70c32_row3_col1 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_70c32_row4_col0 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_70c32_row4_col1 {
#   background-color: #034f7d;
#   color: #f1f1f1;
# }
# #T_70c32_row5_col0 {
#   background-color: #04649d;
#   color: #f1f1f1;
# }
# #T_70c32_row5_col1 {
#   background-color: #1e80b8;
#   color: #f1f1f1;
# }
# #T_70c32_row6_col0 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_70c32_row6_col1 {
#   background-color: #2383ba;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_70c32">
#   <caption>天氣狀況</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_70c32_level0_col0" class="col_heading level0 col0" >Tokyo</th>
#       <th id="T_70c32_level0_col1" class="col_heading level0 col1" >Taipei</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_70c32_level0_row0" class="row_heading level0 row0" >2024-01-Monday</th>
#       <td id="T_70c32_row0_col0" class="data row0 col0" >小雨</td>
#       <td id="T_70c32_row0_col1" class="data row0 col1" >小雨</td>
#     </tr>
#     <tr>
#       <th id="T_70c32_level0_row1" class="row_heading level0 row1" >2024-01-Tuesday</th>
#       <td id="T_70c32_row1_col0" class="data row1 col0" >乾燥</td>
#       <td id="T_70c32_row1_col1" class="data row1 col1" >乾燥</td>
#     </tr>
#     <tr>
#       <th id="T_70c32_level0_row2" class="row_heading level0 row2" >2024-01-Wednesday</th>
#       <td id="T_70c32_row2_col0" class="data row2 col0" >乾燥</td>
#       <td id="T_70c32_row2_col1" class="data row2 col1" >乾燥</td>
#     </tr>
#     <tr>
#       <th id="T_70c32_level0_row3" class="row_heading level0 row3" >2024-01-Thursday</th>
#       <td id="T_70c32_row3_col0" class="data row3 col0" >乾燥</td>
#       <td id="T_70c32_row3_col1" class="data row3 col1" >小雨</td>
#     </tr>
#     <tr>
#       <th id="T_70c32_level0_row4" class="row_heading level0 row4" >2024-01-Friday</th>
#       <td id="T_70c32_row4_col0" class="data row4 col0" >乾燥</td>
#       <td id="T_70c32_row4_col1" class="data row4 col1" >乾燥</td>
#     </tr>
#     <tr>
#       <th id="T_70c32_level0_row5" class="row_heading level0 row5" >2024-01-Saturday</th>
#       <td id="T_70c32_row5_col0" class="data row5 col0" >乾燥</td>
#       <td id="T_70c32_row5_col1" class="data row5 col1" >乾燥</td>
#     </tr>
#     <tr>
#       <th id="T_70c32_level0_row6" class="row_heading level0 row6" >2024-01-Sunday</th>
#       <td id="T_70c32_row6_col0" class="data row6 col0" >乾燥</td>
#       <td id="T_70c32_row6_col1" class="data row6 col1" >乾燥</td>
#     </tr>
#   </tbody>
# </table>

# %%
weather_df = pd.DataFrame(np.random.rand(10,2)*5,
                          index=pd.date_range(start="2024-01-01", periods=10),
                          columns=["Tokyo","Taipei"]
                          )
display(weather_df)
def rain_condition(v):
    if v > 1.75:
        return'乾燥'
    elif v < 2.75:
        return '小雨'
    else:
        return'大雨'
    
def make_pretty(styler):
    styler.set_caption('天氣狀況')
    styler.format(rain_condition)
    styler.format_index(formatter=lambda v:v.strftime('%Y-%m-%A'))
    styler.background_gradient(axis=None,vmin=1,vmax=5, cmap="PuBuGn")
    return styler

s = weather_df.loc['2024-01-01':'2024-01-07'].style.pipe(make_pretty)
s
# Out:
#                Tokyo    Taipei
# 2024-01-01  1.273775  2.066953
# 2024-01-02  1.306121  1.668865
# 2024-01-03  0.865244  2.201782
# 2024-01-04  0.539654  0.125725
# 2024-01-05  3.407248  2.538713
# 2024-01-06  1.265133  4.305055
# 2024-01-07  4.597304  2.704285
# 2024-01-08  3.933456  4.723949
# 2024-01-09  4.776027  4.351396
# 2024-01-10  3.316100  4.900611
# <style type="text/css">
# #T_223bf_row0_col0, #T_223bf_row5_col0 {
#   background-color: #f5ecf5;
#   color: #000000;
# }
# #T_223bf_row0_col1 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_223bf_row1_col0 {
#   background-color: #f4eaf4;
#   color: #000000;
# }
# #T_223bf_row1_col1 {
#   background-color: #e3dded;
#   color: #000000;
# }
# #T_223bf_row2_col0, #T_223bf_row3_col0, #T_223bf_row3_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_223bf_row2_col1 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_223bf_row4_col0 {
#   background-color: #3e94c3;
#   color: #f1f1f1;
# }
# #T_223bf_row4_col1 {
#   background-color: #a1bcda;
#   color: #000000;
# }
# #T_223bf_row5_col1 {
#   background-color: #01746c;
#   color: #f1f1f1;
# }
# #T_223bf_row6_col0 {
#   background-color: #016451;
#   color: #f1f1f1;
# }
# #T_223bf_row6_col1 {
#   background-color: #8cb5d6;
#   color: #000000;
# }
# </style>
# <table id="T_223bf">
#   <caption>天氣狀況</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_223bf_level0_col0" class="col_heading level0 col0" >Tokyo</th>
#       <th id="T_223bf_level0_col1" class="col_heading level0 col1" >Taipei</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_223bf_level0_row0" class="row_heading level0 row0" >2024-01-Monday</th>
#       <td id="T_223bf_row0_col0" class="data row0 col0" >小雨</td>
#       <td id="T_223bf_row0_col1" class="data row0 col1" >乾燥</td>
#     </tr>
#     <tr>
#       <th id="T_223bf_level0_row1" class="row_heading level0 row1" >2024-01-Tuesday</th>
#       <td id="T_223bf_row1_col0" class="data row1 col0" >小雨</td>
#       <td id="T_223bf_row1_col1" class="data row1 col1" >小雨</td>
#     </tr>
#     <tr>
#       <th id="T_223bf_level0_row2" class="row_heading level0 row2" >2024-01-Wednesday</th>
#       <td id="T_223bf_row2_col0" class="data row2 col0" >小雨</td>
#       <td id="T_223bf_row2_col1" class="data row2 col1" >乾燥</td>
#     </tr>
#     <tr>
#       <th id="T_223bf_level0_row3" class="row_heading level0 row3" >2024-01-Thursday</th>
#       <td id="T_223bf_row3_col0" class="data row3 col0" >小雨</td>
#       <td id="T_223bf_row3_col1" class="data row3 col1" >小雨</td>
#     </tr>
#     <tr>
#       <th id="T_223bf_level0_row4" class="row_heading level0 row4" >2024-01-Friday</th>
#       <td id="T_223bf_row4_col0" class="data row4 col0" >乾燥</td>
#       <td id="T_223bf_row4_col1" class="data row4 col1" >乾燥</td>
#     </tr>
#     <tr>
#       <th id="T_223bf_level0_row5" class="row_heading level0 row5" >2024-01-Saturday</th>
#       <td id="T_223bf_row5_col0" class="data row5 col0" >小雨</td>
#       <td id="T_223bf_row5_col1" class="data row5 col1" >乾燥</td>
#     </tr>
#     <tr>
#       <th id="T_223bf_level0_row6" class="row_heading level0 row6" >2024-01-Sunday</th>
#       <td id="T_223bf_row6_col0" class="data row6 col0" >乾燥</td>
#       <td id="T_223bf_row6_col1" class="data row6 col1" >乾燥</td>
#     </tr>
#   </tbody>
# </table>

# %%
np.random.seed(1234)
weather_df = pd.DataFrame(np.random.rand(10,2)*5,
                          index=pd.date_range(start="2024-01-01", periods=10),
                          columns=["Tokyo","Taipei"]
                          )
display(weather_df)
def rain_condition(v):
    if v < 1.75:
        return "乾燥"
    elif v < 2.75:
        return "小雨"
    else:
        return "大雨"

def make_pretty(styler):
    styler.set_caption("天氣狀況")
    styler.format(rain_condition)
    styler.format_index(formatter=lambda v:v.strftime("%Y/%m/%d %A"))
    styler.background_gradient(axis=None,vmin=1,vmax=5,cmap="PuBuGn")
    return styler

s = weather_df.loc['2024-01-01':'2024-01-07'].style.pipe(make_pretty)
s.to_excel('weather_condition.xlsx')
# Out:
#                Tokyo    Taipei
# 2024-01-01  0.957597  3.110544
# 2024-01-02  2.188639  3.926793
# 2024-01-03  3.899879  1.362963
# 2024-01-04  1.382321  4.009361
# 2024-01-05  4.790697  4.379663
# 2024-01-06  1.789086  2.504976
# 2024-01-07  3.417315  3.563510
# 2024-01-08  1.851254  2.805981
# 2024-01-09  2.515416  0.068842
# 2024-01-10  3.864133  4.413206
