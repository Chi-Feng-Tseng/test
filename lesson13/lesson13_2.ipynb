# %% [markdown]
# https://www.perplexity.ai/search/9871d0a8-7c4d-4f84-b02c-380c0c477c7d

# %%
import matplotlib.pyplot as plt

figure, axes = plt.subplots()
x = [0, 1, 2]
y = [3, 4, 5]
axes.plot(x, y, label='line plot')
plt.show()

# %%
import matplotlib.pyplot as plt

figure, axes = plt.subplots()
x = [0, 1, 2]
y = [3, 4, 5]
axes.plot(x, y, label='line plot')
axes.set_title('Line plot on Existing Axes')  #將圖表的title放上去
axes.legend()  #圖表的左上角多了'line plot'的顯示
plt.show()

# %%
import matplotlib.pyplot as plt

figure, axes = plt.subplots()
x = [0, 1, 2]
y = [3, 4, 5]
axes.plot(x, y, marker='o',label='line plot',linestyle='-.',color='r',markersize=10,linewidth=2)
axes.set_title('Line plot on Existing Axes')  
axes.legend()  
plt.show()

# %%
# title 不能顯示中文
import matplotlib.pyplot as plt

figure, axes = plt.subplots()
x = [0, 1, 2]
y = [3, 4, 5]
axes.plot(x, y, marker='o',label='line plot',linestyle='-.',color='r',markersize=10,linewidth=2)
axes.set_title('折線圖')  
axes.legend()  
plt.show()
# Out:
# c:\Users\user\miniconda3\envs\python2_4\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 25240 (\N{CJK UNIFIED IDEOGRAPH-6298}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\miniconda3\envs\python2_4\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 32218 (\N{CJK UNIFIED IDEOGRAPH-7DDA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\miniconda3\envs\python2_4\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 22294 (\N{CJK UNIFIED IDEOGRAPH-5716}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# !pip install wget

# %%
#下載中文字型
import wget
wget.download("https://github.com/roberthsu2003/machine_learning/raw/refs/heads/main/source_data/ChineseFont.ttf")
# Out:
# 'ChineseFont.ttf'

# %%
import matplotlib.pyplot as plt
from matplotlib.font_manager import fontManager  #要顯示中文，需多打這兩行
import matplotlib as mpl

fontManager.addfont('chineseFont.ttf')
mpl.rc('font', family = 'chineseFont')

figure, axes = plt.subplots()
x = [0, 1, 2]
y = [3, 4, 5]
axes.plot(x, y, marker='o',label='學生1',linestyle='-.',color='r',markersize=10,linewidth=2)
axes.set_title('折線圖')  
axes.legend()  
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.font_manager import fontManager  #要顯示中文，需多打這兩行
import matplotlib as mpl

fontManager.addfont('chineseFont.ttf')
mpl.rc('font', family = 'chineseFont')

figure, axes = plt.subplots()
x = [1, 2, 3]
y = [3, 4, 5]
axes.plot(x, y, marker='o',label='學生1',linestyle='-.',color='r',markersize=10,linewidth=2)
axes.set_title('折線圖') 
axes.set_xticks([1, 2, 3],['第1','第2','第3'])  #這裡的第1, 第2, 第3要對應X的1, 2, 3
axes.set_yticks([3, 4, 5],['3', '4','5'])   #這裡的3, 4, 5要對應y的3, 4, 5
axes.legend()  
plt.show()
