# %% [markdown]
# https://www.perplexity.ai/search/dbe2dcd6-bbdf-488c-9e30-da78af563e02

# %% [markdown]
# ### student1 = {'國文':78, '英文':80, '數學':92, '歷史':75, '探索':85}
# ### student2 = {'國文':90, '英文':75, '數學':98, '歷史':65, '探索':75}

# %%
# 自己做的
import matplotlib.pyplot as plt
from matplotlib.font_manager import fontManager  
import matplotlib as mpl

fontManager.addfont('chineseFont.ttf')
mpl.rc('font', family = 'chineseFont')


figure, axes1 = plt.subplots()
x = [1, 2, 3, 4, 5]
y = [78, 80, 92, 75, 85]
axes1.plot(x, y, marker='o',label='student1',linestyle='-.',color='r',markersize=10,linewidth=2)
axes1.set_title('折線圖') 
axes1.set_xticks([1, 2, 3, 4, 5],['國文','英文','數學','歷史', '探索'])  
axes1.set_yticks([78, 80, 92, 75, 85],['78', '80', '92', '75', '85'])   
axes1.legend()  

figure, axes2 = plt.subplots()
x = [1, 2, 3, 4, 5]
y = [90, 75, 98, 65, 75]
axes2.plot(x, y, marker='*',label='student2',linestyle='-.',color='y',markersize=10,linewidth=2)
axes2.set_title('折線圖') 
axes2.set_xticks([1, 2, 3, 4, 5],['國文','英文','數學','歷史', '探索'])  
axes2.set_yticks([90, 75, 98, 65, 75],['90', '75', '98', '65', '75'])   
axes2.legend()  

plt.show()

# %%
import matplotlib.pyplot as plt

student1 = {'國文':78, '英文':80, '數學':92, '歷史':75, '探索':85}
student2 = {'國文':90, '英文':75, '數學':98, '歷史':65, '探索':75}

subjects = list(student1.keys())
student1_value = list(student1.values())
student2_value = list(student2.values())

figure = plt.figure(figsize=(8, 5),dpi=150,facecolor = '#eeeeee')
axes = figure.add_subplot(1, 1, 1)
plt.show()

# %%
import matplotlib.pyplot as plt

student1 = {'國文':78, '英文':80, '數學':92, '歷史':75, '探索':85}
student2 = {'國文':90, '英文':75, '數學':98, '歷史':65, '探索':75}

student1.keys()
# Out:
# dict_keys(['國文', '英文', '數學', '歷史', '探索'])

# %%
import matplotlib.pyplot as plt

student1 = {'國文':78, '英文':80, '數學':92, '歷史':75, '探索':85}
student2 = {'國文':90, '英文':75, '數學':98, '歷史':65, '探索':75}

subjects = list(student1.keys())
student1_value = list(student1.values())
student2_value = list(student2.values())


figure = plt.figure(figsize=(8, 5),dpi=130,facecolor='#eeeeee')
axes = figure.add_subplot(1, 1, 1)
axes.plot(subjects,student1_value,marker='o',label="曾xx")
axes.plot(subjects,student2_value,marker='*',linestyle='-.',label="張xx")
axes.set_title('曾XX VS 張XX 成績比較')
axes.set_xlabel('科目')
axes.set_ylabel('分數')
axes.legend() 
axes.grid(axis='y',color='blue',alpha=0.5,linestyle=':')   

plt.show()

# %%
import matplotlib.pyplot as plt

student1 = {'國文':78, '英文':80, '數學':92, '歷史':75, '探索':85}
student2 = {'國文':90, '英文':75, '數學':98, '歷史':65, '探索':75}

subjects = list(student1.keys())
student1_value = list(student1.values())
student2_value = list(student2.values())


figure = plt.figure(figsize=(8, 5),dpi=130,facecolor='#eeeeee')
axes = figure.add_subplot(1, 1, 1)
axes.plot(subjects,student1_value,marker='o',label="曾xx")
axes.plot(subjects,student2_value,marker='*',linestyle='-.',label="張xx")
axes.set_title('曾XX VS 張XX 成績比較')
axes.set_xlabel('科目')
axes.set_ylabel('分數')
axes.legend() 

xlocations = axes.get_xticks()
for index in range(len(xlocations)):
    x = xlocations[index]
    student1_y = student1_value[index]
    student2_y = student2_value[index]

    axes.annotate(str(student1_y),(x,student1_y))
    axes.annotate(str(student2_y),(x,student2_y))


axes.grid(axis='y',color='blue',alpha=0.1,linestyle=':')   

plt.show()

# %%
import matplotlib.pyplot as plt

student1 = {'國文':78, '英文':80, '數學':92, '歷史':75, '探索':85}
student2 = {'國文':90, '英文':75, '數學':98, '歷史':65, '探索':75}

subjects = list(student1.keys())
student1_value = list(student1.values())
student2_value = list(student2.values())


figure = plt.figure(figsize=(8, 5),dpi=130,facecolor='#eeeeee')
axes = figure.add_subplot(1, 1, 1)
axes.plot(subjects,student1_value,marker='o',label="曾xx")
axes.plot(subjects,student2_value,marker='*',linestyle='-.',label="張xx")
axes.set_title('曾XX VS 張XX')
axes.set_xlabel('科目')
axes.set_ylabel('分數')
axes.legend() 

xlocations = axes.get_xticks()
for index in range(len(xlocations)):
    x = xlocations[index]
    student1_y = student1_value[index]
    student2_y = student2_value[index]

    axes.annotate(str(student1_y),(x-0.05,student1_y+1))
    axes.annotate(str(student2_y),(x-0.05,student2_y+1))


axes.grid(axis='y',color='blue',alpha=0.1,linestyle=':')   

plt.show()

# %%
import matplotlib.pyplot as plt

student1 = {'國文':78, '英文':80, '數學':92, '歷史':75, '探索':85}
student2 = {'國文':90, '英文':75, '數學':98, '歷史':65, '探索':75}

subjects = list(student1.keys())
student1_value = list(student1.values())
student2_value = list(student2.values())

figure = plt.figure(figsize=(8, 5),dpi=130,facecolor='#eeeeee')
axes = figure.add_subplot(1, 1, 1)
axes.plot(subjects,student1_value,marker='o',label="曾xx")
axes.plot(subjects,student2_value,marker='*',linestyle='-.',label="張xx")
axes.set_title('曾XX VS 張XX')
axes.set_xlabel('科目')
axes.set_ylabel('分數')
axes.legend() 

xlocations = axes.get_xticks()
for index in range(len(xlocations)):
    x = xlocations[index]
    student1_y = student1_value[index]
    student2_y = student2_value[index]
    # print("x座標:",x)
    # print("s1_y_座標:",student1_y)
    # print("s2_y_座標:",student2_y)
    # print("==================")

    axes.annotate(str(student1_y),(x-0.05,student1_y+1))
    axes.annotate(str(student2_y),(x-0.05,student2_y+1))

    axes.set_xlim(-0.5, 4.5) #調整X軸的範圍
    axes.set_ylim(65, 105)   #調整y軸的範圍

axes.grid(axis='y',color='blue',alpha=0.1,linestyle=':')   

plt.show()

# %%
import matplotlib.pyplot as plt

student1 = {'國文':78, '英文':80, '數學':92, '歷史':75, '探索':85}
student2 = {'國文':90, '英文':75, '數學':98, '歷史':65, '探索':75}

subjects = list(student1.keys())
student1_value = list(student1.values())
student2_value = list(student2.values())


figure = plt.figure(figsize=(8, 5),dpi=150,facecolor='#eeeeee')
axes = figure.add_subplot(1, 1, 1)
axes.plot(subjects,student1_value,marker='o',label="曾xx")
axes.plot(subjects,student2_value,marker='*',linestyle='-.',label="張xx")
axes.set_title('曾XX VS 張XX')
axes.set_xlabel('科目')
axes.set_ylabel('分數')
axes.legend() 

xlocations = axes.get_xticks()
for index in range(len(xlocations)):
    x = xlocations[index]
    student1_y = student1_value[index]
    student2_y = student2_value[index]
    # print("x座標:",x)
    # print("s1_y_座標:",student1_y)
    # print("s2_y_座標:",student2_y)
    # print("==================")

    axes.annotate(str(student1_y),(x-0.05,student1_y+1))
    axes.annotate(str(student2_y),(x-0.05,student2_y+1))

    if student2_y == 98:   #在98分上面加一個箭頭
        axes.annotate(str(student2_y),(x,student2_y),xytext=(x+0.3, student2_y+5), arrowprops=dict(facecolor='red', shrink=0.05))
    else:
        axes.annotate(str(student2_y),(x-0.05,student2_y+1))

    axes.set_xlim(-0.5, 4.5) #調整X軸的範圍
    axes.set_ylim(65, 105)   #調整y軸的範圍

axes.grid(axis='y',color='blue',alpha=0.1,linestyle=':')   

plt.show()
