# %% [markdown]
# https://www.perplexity.ai/search/00e886a4-379f-4394-ba54-88dc43881fa0

# %%
import numpy as np
import pandas as pd

scores = np.random.randint(50, 101, size=(50, 5))

# %%
scores
# Out:
# array([[ 70,  70,  57,  96,  78],
#        [ 96,  70,  90,  65,  69],
#        [ 88,  98,  92,  76,  50],
#        [ 73,  65,  80,  61,  99],
#        [ 65,  90,  53,  90,  71],
#        [ 76,  81,  88,  90,  98],
#        [ 81,  50,  92,  57,  67],
#        [ 61,  96,  80,  57,  96],
#        [ 57,  61,  66,  68,  55],
#        [ 95,  99,  52,  75,  85],
#        [ 67,  90,  98,  70,  95],
#        [ 90,  60,  85,  87,  97],
#        [ 96,  59,  75,  93,  87],
#        [ 59,  71,  57,  81,  95],
#        [ 85,  55,  79,  86,  52],
#        [ 55,  70,  88,  94,  73],
#        [ 76,  94,  96,  57,  56],
#        [ 66,  99,  85,  95,  72],
#        [ 72,  95,  55,  94,  94],
#        [ 53,  62,  55,  92,  60],
#        [ 79,  63,  83,  87,  80],
#        [ 82,  68,  96,  81,  83],
#        [ 85,  82,  56,  62,  58],
#        [ 93,  68,  97,  65,  99],
#        [ 53,  62,  90,  72,  77],
#        [ 75,  81,  81,  68,  59],
#        [ 69,  71, 100,  90,  73],
#        [ 74,  69,  94,  66,  85],
#        [ 68,  86,  68,  84,  81],
#        [ 56,  74,  87,  62,  58],
#        [ 75,  76,  58,  57,  84],
#        [ 69,  82,  94,  74,  73],
#        [ 96,  52,  98,  79,  76],
#        [ 55,  50,  59,  73,  84],
#        [ 86,  51,  99,  73,  92],
#        [ 87,  94,  53,  73,  79],
#        [ 77,  68,  81,  90,  50],
#        [ 86,  89,  90,  54,  89],
#        [ 67,  81,  86,  91,  93],
#        [ 82,  72,  70,  65,  98],
#        [ 82,  51,  68,  80,  83],
#        [ 93,  51,  86,  94,  60],
#        [ 63,  70,  85,  80,  81],
#        [ 53,  74,  51,  87,  53],
#        [ 51,  56,  93,  58,  75],
#        [ 69,  98,  57,  57,  66],
#        [ 78,  60,  91,  77,  72],
#        [ 70,  50,  71,  52,  58],
#        [ 98,  54,  87,  58,  95],
#        [ 79,  51,  88,  70,  66]], dtype=int32)

# %%
pd.DataFrame(scores)  # 增加可讀性
# Out:
#      0   1    2   3   4
# 0   70  70   57  96  78
# 1   96  70   90  65  69
# 2   88  98   92  76  50
# 3   73  65   80  61  99
# 4   65  90   53  90  71
# 5   76  81   88  90  98
# 6   81  50   92  57  67
# 7   61  96   80  57  96
# 8   57  61   66  68  55
# 9   95  99   52  75  85
# 10  67  90   98  70  95
# 11  90  60   85  87  97
# 12  96  59   75  93  87
# 13  59  71   57  81  95
# 14  85  55   79  86  52
# 15  55  70   88  94  73
# 16  76  94   96  57  56
# 17  66  99   85  95  72
# 18  72  95   55  94  94
# 19  53  62   55  92  60
# stu4   73  65   80  61  99
# stu5   65  90   53  90  71
# stu6   76  81   88  90  98
# stu7   81  50   92  57  67
# stu8   61  96   80  57  96
# stu9   57  61   66  68  55
# stu10  95  99   52  75  85
# stu11  67  90   98  70  95
# stu12  90  60   85  87  97
# stu13  96  59   75  93  87
# stu14  59  71   57  81  95
# stu15  85  55   79  86  52
# stu16  55  70   88  94  73
# stu17  76  94   96  57  56
# stu18  66  99   85  95  72
# stu19  72  95   55  94  94
# stu20  53  62   55  92  60
# stu21  79  63   83  87  80
# stu22  82  68   96  81  83
# stu23  85  82   56  62  58
# stu24  93  68   97  65  99
# stu25  53  62   90  72  77
# stu26  75  81   81  68  59
# stu27  69  71  100  90  73
# stu28  74  69   94  66  85
# stu29  68  86   68  84  81
# stu30  56  74   87  62  58
# stu31  75  76   58  57  84
# stu32  69  82   94  74  73
# stu33  96  52   98  79  76
# stu34  55  50   59  73  84
# stu35  86  51   99  73  92
# stu36  87  94   53  73  79
# stu37  77  68   81  90  50
# stu38  86  89   90  54  89
# stu39  67  81   86  91  93
# stu40  82  72   70  65  98
# stu41  82  51   68  80  83
# stu42  93  51   86  94  60
# stu43  63  70   85  80  81
# stu44  53  74   51  87  53
# stu45  51  56   93  58  75
# stu46  69  98   57  57  66
# stu47  78  60   91  77  72
# stu48  70  50   71  52  58
# stu49  98  54   87  58  95
# stu50  79  51   88  70  66

# %%
import matplotlib.pyplot as plt

df = pd.DataFrame(scores,
             columns = ["國文","英文","地理","人文","氣候"],
             index=[f"stu{i}" for i in range(1,51)]
             )
name1 = df.loc['stu1'].name
name2 = df.loc['stu2'].name       
figure = plt.figure(figsize=(8, 5),dpi=150,facecolor='#eeeeee')
axes = figure.add_subplot(1,1,1)
axes.plot(df.columns,df.loc['stu1'],marker='o',label=name1)
axes.plot(df.columns,df.loc['stu2'],marker='o',linestyle='-.',label=name2)
axes.set_title(f"{name1} vs {name2}")
axes.set_xlabel("科目")
axes.set_ylabel("分數")
axes.legend()
xlocations = axes.get_xticks()
for index in range(len(xlocations)):
    x = xlocations[index]
    student1_y = df.loc['stu1'][index]
    student2_y = df.loc['stu2'][index]
    # print("x座標:",x)
    # print("s1_y_座標:",student1_y)
    # print("s2_y_座標:",student2_y)
    # print("==================")
    axes.annotate(str(student1_y),(x-0.05,student1_y+1))
    if student2_y == 98:
        axes.annotate(str(student2_y),(x,student2_y),xytext=(x+0.3, student2_y+5), arrowprops=dict(facecolor='red', shrink=0.05))
    else:
        axes.annotate(str(student2_y),(x-0.05,student2_y+1))
    axes.set_xlim(-0.5,4.5)
    axes.set_ylim(60,105)
axes.grid(axis='y',color='blue',alpha=0.1,linestyle=':')
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12820\2418271061.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   student1_y = df.loc['stu1'][index]
# C:\Users\user\AppData\Local\Temp\ipykernel_12820\2418271061.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   student2_y = df.loc['stu2'][index]
